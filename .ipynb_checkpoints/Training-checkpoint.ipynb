# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('all_data.csv')

# %%
df.head()
# Out:
#          Date         Open         High          Low        Close Symbol  \
# 0  2022-05-07  2694.991943  2696.652832  2599.523438  2636.093018    ETH
# 1  2022-05-08  2636.121826  2638.830566  2498.430176  2517.459961    ETH
# 2  2022-05-09  2518.508301  2528.258057  2238.062744  2245.430420    ETH
# 3  2022-05-10  2242.650391  2450.760254  2206.756836  2343.510986    ETH
# 4  2022-05-11  2342.754150  2441.079346  2018.855591  2072.108643    ETH
#
#   Cryptocurrency Name
# 0            Ethereum
# 1            Ethereum
# 2            Ethereum
# 3            Ethereum
# 4            Ethereum

# %%
df.dtypes
# Out:
# Date                    object
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Symbol                  object
# Cryptocurrency Name     object
# dtype: object

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date                   datetime64[ns]
# Open                          float64
# High                          float64
# Low                           float64
# Close                         float64
# Symbol                         object
# Cryptocurrency Name            object
# dtype: object

# %%
df['Symbol'].unique()
# Out:
# array(['ETH', 'BTC', 'USDT', 'USDC', 'BUSD', 'XRP', 'RAD', 'SOL', 'TUSD',
#        'BNB', 'ARB', 'LTC', 'UMA', 'DOGE', 'IDEX', 'MATIC', 'ADA', 'GALA',
#        'RNDR', 'AVAX', 'LINK', 'CFX', 'OP', 'TRX', 'FLOKI', 'FIL',
#        'JASMY', 'INJ', 'SHIB', 'MTL', 'FTM', 'DOT', 'EOS', 'APT', 'AERGO',
#        'BETA', 'LDO', 'ATOM', 'BLUR', 'WOO', 'XMR', 'STX', 'KAVA', 'ETC',
#        'UNI', 'LUNC', 'CTC', 'SXP', 'BSV', 'ICP', 'POLYX', 'BETH', 'DYDX',
#        'SSV', 'MAGIC', 'CHZ', 'CRV', 'OG', 'ALGO', 'ORN', 'ICX', 'LINA',
#        'XLM', 'NEO', 'KCS', 'AGI', 'TOMO', 'FET', 'SAND', 'BCH', 'AAVE',
#        'APE', 'PEOPLE', 'BEL', 'NEAR', 'MINA', 'JOE', 'MANA', 'CAKE',
#        'VET', 'XRD', 'IOTX', 'EGLD', 'USDP', 'VAL', 'KISHU', 'IMX', 'MKR',
#        'WIN', 'HBAR', 'GTC', 'ALPINE', 'TVK', 'SNX', 'BNX', 'COCOS',
#        'PAXG', 'SUSHI', 'CTSI', 'QNT'], dtype=object)

# %%
data = df.copy()

# %%
cols_to_encode = ['Symbol', 'Cryptocurrency Name']
le = LabelEncoder()
data[cols_to_encode] = data[cols_to_encode].apply(le.fit_transform)

# %%
df
# Out:
#             Date         Open         High          Low        Close Symbol  \
# 0     2022-05-07  2694.991943  2696.652832  2599.523438  2636.093018    ETH
# 1     2022-05-08  2636.121826  2638.830566  2498.430176  2517.459961    ETH
# 2     2022-05-09  2518.508301  2528.258057  2238.062744  2245.430420    ETH
# 3     2022-05-10  2242.650391  2450.760254  2206.756836  2343.510986    ETH
# 4     2022-05-11  2342.754150  2441.079346  2018.855591  2072.108643    ETH
# ...          ...          ...          ...          ...          ...    ...
# 35425 2023-05-02   111.993942   114.199486   111.779877   113.374268    QNT
# 35426 2023-05-03   113.381187   113.524734   110.651741   112.499992    QNT
# 35427 2023-05-04   112.509727   113.415794   111.674637   112.236458    QNT
# 35428 2023-05-05   112.238022   114.920525   111.847145   114.069908    QNT
# 35429 2023-05-07   111.235001   111.494591   109.653465   109.961952    QNT
#
#       Cryptocurrency Name
# 0                Ethereum
# 1                Ethereum
# 2                Ethereum
# 3                Ethereum
# 4                Ethereum
# ...                   ...
# 35425               Quant
# 35426               Quant
# 35427               Quant
# 35428               Quant
# 35429               Quant
#
# [35430 rows x 7 columns]

# %%
data
# Out:
#             Date         Open         High          Low        Close  Symbol  \
# 0     2022-05-07  2694.991943  2696.652832  2599.523438  2636.093018      34
# 1     2022-05-08  2636.121826  2638.830566  2498.430176  2517.459961      34
# 2     2022-05-09  2518.508301  2528.258057  2238.062744  2245.430420      34
# 3     2022-05-10  2242.650391  2450.760254  2206.756836  2343.510986      34
# 4     2022-05-11  2342.754150  2441.079346  2018.855591  2072.108643      34
# ...          ...          ...          ...          ...          ...     ...
# 35425 2023-05-02   111.993942   114.199486   111.779877   113.374268      72
# 35426 2023-05-03   113.381187   113.524734   110.651741   112.499992      72
# 35427 2023-05-04   112.509727   113.415794   111.674637   112.236458      72
# 35428 2023-05-05   112.238022   114.920525   111.847145   114.069908      72
# 35429 2023-05-07   111.235001   111.494591   109.653465   109.961952      72
#
#        Cryptocurrency Name
# 0                       31
# 1                       31
# 2                       31
# 3                       31
# 4                       31
# ...                    ...
# 35425                   70
# 35426                   70
# 35427                   70
# 35428                   70
# 35429                   70
#
# [35430 rows x 7 columns]

# %%
data.isna().sum()
# Out:
# Date                   0
# Open                   0
# High                   0
# Low                    0
# Close                  0
# Symbol                 0
# Cryptocurrency Name    0
# dtype: int64
